# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshikaprakash/nlpelective/blob/main/VanshikaLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install nltk
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from collections import Counter
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
Text = """
Natural Language Processing (NLP) is a branch of Artificial Intelligence that enables computers to understand, interpret, and generate human language. It combines computer science, linguistics, and machine learning to process text and speech data.

NLP helps machines analyze large amounts of natural language data and extract meaningful information from it. It allows systems to perform tasks such as language translation, sentiment analysis, text summarization, speech recognition, and chatbot interactions.
"""

# %%
nltk.download('punkt_tab')
tokens = word_tokenize(Text)
print("Tokens:/n", tokens)
# Out:
# Tokens:/n ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', 'that', 'enables', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.', 'It', 'combines', 'computer', 'science', ',', 'linguistics', ',', 'and', 'machine', 'learning', 'to', 'process', 'text', 'and', 'speech', 'data', '.', 'NLP', 'helps', 'machines', 'analyze', 'large', 'amounts', 'of', 'natural', 'language', 'data', 'and', 'extract', 'meaningful', 'information', 'from', 'it', '.', 'It', 'allows', 'systems', 'to', 'perform', 'tasks', 'such', 'as', 'language', 'translation', ',', 'sentiment', 'analysis', ',', 'text', 'summarization', ',', 'speech', 'recognition', ',', 'and', 'chatbot', 'interactions', '.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
stop_words = set(stopwords.words("english"))
filtered_words = [word for word in tokens if word.lower() not in stop_words]

print("Original Words:", tokens)
print("After Stopword Removal:", filtered_words)
# Out:
# Original Words: ['natural', 'language', 'processing', 'nlp', 'is', 'a', 'branch', 'of', 'artificial', 'intelligence', 'that', 'enables', 'computers', 'to', 'understand', 'interpret', 'and', 'generate', 'human', 'language', 'it', 'combines', 'computer', 'science', 'linguistics', 'and', 'machine', 'learning', 'to', 'process', 'text', 'and', 'speech', 'data', 'nlp', 'helps', 'machines', 'analyze', 'large', 'amounts', 'of', 'natural', 'language', 'data', 'and', 'extract', 'meaningful', 'information', 'from', 'it', 'it', 'allows', 'systems', 'to', 'perform', 'tasks', 'such', 'as', 'language', 'translation', 'sentiment', 'analysis', 'text', 'summarization', 'speech', 'recognition', 'and', 'chatbot', 'interactions']
# ...

# %%
tokens = [word.lower() for word in tokens if word.isalpha()]
print("After punctuation:/n", tokens)
# Out:
# After punctuation:/n ['natural', 'language', 'processing', 'nlp', 'is', 'a', 'branch', 'of', 'artificial', 'intelligence', 'that', 'enables', 'computers', 'to', 'understand', 'interpret', 'and', 'generate', 'human', 'language', 'it', 'combines', 'computer', 'science', 'linguistics', 'and', 'machine', 'learning', 'to', 'process', 'text', 'and', 'speech', 'data', 'nlp', 'helps', 'machines', 'analyze', 'large', 'amounts', 'of', 'natural', 'language', 'data', 'and', 'extract', 'meaningful', 'information', 'from', 'it', 'it', 'allows', 'systems', 'to', 'perform', 'tasks', 'such', 'as', 'language', 'translation', 'sentiment', 'analysis', 'text', 'summarization', 'speech', 'recognition', 'and', 'chatbot', 'interactions']

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]
print("After stemming:/n", stemmed_words)
# Out:
# After stemming:/n ['natur', 'languag', 'process', 'nlp', 'branch', 'artifici', 'intellig', 'enabl', 'comput', 'understand', 'interpret', 'gener', 'human', 'languag', 'combin', 'comput', 'scienc', 'linguist', 'machin', 'learn', 'process', 'text', 'speech', 'data', 'nlp', 'help', 'machin', 'analyz', 'larg', 'amount', 'natur', 'languag', 'data', 'extract', 'meaning', 'inform', 'allow', 'system', 'perform', 'task', 'languag', 'translat', 'sentiment', 'analysi', 'text', 'summar', 'speech', 'recognit', 'chatbot', 'interact']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
print("After lemmatization:/n", lemmatized_words)
# Out:
# After lemmatization:/n ['natural', 'language', 'processing', 'nlp', 'branch', 'artificial', 'intelligence', 'enables', 'computer', 'understand', 'interpret', 'generate', 'human', 'language', 'combine', 'computer', 'science', 'linguistics', 'machine', 'learning', 'process', 'text', 'speech', 'data', 'nlp', 'help', 'machine', 'analyze', 'large', 'amount', 'natural', 'language', 'data', 'extract', 'meaningful', 'information', 'allows', 'system', 'perform', 'task', 'language', 'translation', 'sentiment', 'analysis', 'text', 'summarization', 'speech', 'recognition', 'chatbot', 'interaction']

# %%
word_frequency = Counter(lemmatized_words)
print("Word Frequency:/n", word_frequency)
# Out:
# Word Frequency:/n Counter({'language': 4, 'natural': 2, 'nlp': 2, 'computer': 2, 'machine': 2, 'text': 2, 'speech': 2, 'data': 2, 'processing': 1, 'branch': 1, 'artificial': 1, 'intelligence': 1, 'enables': 1, 'understand': 1, 'interpret': 1, 'generate': 1, 'human': 1, 'combine': 1, 'science': 1, 'linguistics': 1, 'learning': 1, 'process': 1, 'help': 1, 'analyze': 1, 'large': 1, 'amount': 1, 'extract': 1, 'meaningful': 1, 'information': 1, 'allows': 1, 'system': 1, 'perform': 1, 'task': 1, 'translation': 1, 'sentiment': 1, 'analysis': 1, 'summarization': 1, 'recognition': 1, 'chatbot': 1, 'interaction': 1})

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(" ".join(filtered_words))

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
